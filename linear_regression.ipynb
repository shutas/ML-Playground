# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import mglearn

# %matplotlib notebook
# %matplotlib inline

# %%
# Plot one-dimensional wave dataset
mglearn.plots.plot_linear_regression_wave()
# Out:
# w[0]: 0.393906  b: -0.031804
